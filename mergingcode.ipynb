# %%
import os
import shutil
import csv

# Define paths
media_folder = "media"
nlp_folder = "transcripts/nlp_references"
combined_folder = "combined"

# Ensure the combined folder exists
os.makedirs(combined_folder, exist_ok=True)

# Get all MP3 files in the media folder
mp3_files = {os.path.splitext(f)[0]: os.path.join(media_folder, f) for f in os.listdir(media_folder) if f.endswith('.mp3')}

# Process each corresponding NLP file
for base_name, mp3_path in mp3_files.items():
    nlp_path = os.path.join(nlp_folder, base_name + ".nlp")
    txt_output_path = os.path.join(combined_folder, base_name, base_name + ".txt")

    # Check if the corresponding NLP file exists
    if os.path.exists(nlp_path):
        # Create a unique folder for this file combination
        folder_path = os.path.join(combined_folder, base_name)
        os.makedirs(folder_path, exist_ok=True)

        # Extract words from NLP file
        words = []
        with open(nlp_path, 'r', encoding='utf-8') as nlp_file:
            reader = csv.reader(nlp_file, delimiter='|')
            next(reader)  # Skip header row

            for row in reader:
                if row:
                    words.append(row[0])  # Extract token

        # Save extracted words to a .txt file
        with open(txt_output_path, 'w', encoding='utf-8') as txt_file:
            txt_file.write(" ".join(words))  # Space-separated words

        # Move MP3 file into the folder
        shutil.move(mp3_path, os.path.join(folder_path, base_name + ".mp3"))

        print(f"Processed {base_name}: Folder created with .mp3 and .txt file.")

    else:
        print(f"Skipping {base_name}: No corresponding NLP file found.")
# Out:
# Processed 2020-03-0230487MTN-Ghana-2019-Annual-Results-Call: Folder created with .mp3 and .txt file.
# Processed 2020-Annual-Results-Call-Recording: Folder created with .mp3 and .txt file.
# Processed 4329526: Folder created with .mp3 and .txt file.
# Processed 4351517: Folder created with .mp3 and .txt file.
# Processed 4372696: Folder created with .mp3 and .txt file.
# Processed 4420696: Folder created with .mp3 and .txt file.
# Processed 4423872: Folder created with .mp3 and .txt file.
# Processed 4426736: Folder created with .mp3 and .txt file.
# Processed 4430051: Folder created with .mp3 and .txt file.
# Processed 4432298: Folder created with .mp3 and .txt file.
# Processed 4443871: Folder created with .mp3 and .txt file.
# Processed 4443920: Folder created with .mp3 and .txt file.
# Processed 4446796: Folder created with .mp3 and .txt file.
# Processed 4448760: Folder created with .mp3 and .txt file.
# Processed 4449269: Folder created with .mp3 and .txt file.
# Processed 4450488: Folder created with .mp3 and .txt file.
# Processed 4450779: Folder created with .mp3 and .txt file.
# Processed 4452058: Folder created with .mp3 and .txt file.
# Processed 4453076: Folder created with .mp3 and .txt file.
# Processed 4453085: Folder created with .mp3 and .txt file.
# Processed 4453225: Folder created with .mp3 and .txt file.
# Processed 4461799: Folder created with .mp3 and .txt file.
# Processed 4462231: Folder created with .mp3 and .txt file.
# Processed 4463259: Folder created with .mp3 and .txt file.
# Processed 4463693: Folder created with .mp3 and .txt file.
# Processed 4464164: Folder created with .mp3 and .txt file.
# Processed 4466251: Folder created with .mp3 and .txt file.
# Processed 4466399: Folder created with .mp3 and .txt file.
# Processed 4466607: Folder created with .mp3 and .txt file.
# Processed 4466718: Folder created with .mp3 and .txt file.
# Processed 4466797: Folder created with .mp3 and .txt file.
# Processed 4467071: Folder created with .mp3 and .txt file.
# Processed 4467079: Folder created with .mp3 and .txt file.
# Processed 4467434: Folder created with .mp3 and .txt file.
# Processed 4467717: Folder created with .mp3 and .txt file.
# Processed 4468000: Folder created with .mp3 and .txt file.
# Processed 4468307: Folder created with .mp3 and .txt file.
# Processed 4468639: Folder created with .mp3 and .txt file.
# Processed 4468647: Folder created with .mp3 and .txt file.
# Processed 4468654: Folder created with .mp3 and .txt file.
# Processed 4468678: Folder created with .mp3 and .txt file.
# Processed 4468679: Folder created with .mp3 and .txt file.
# Processed 4468715: Folder created with .mp3 and .txt file.
# Processed 4468919: Folder created with .mp3 and .txt file.
# Processed 4469075: Folder created with .mp3 and .txt file.
# Processed 4469088: Folder created with .mp3 and .txt file.
# Processed 4469184: Folder created with .mp3 and .txt file.
# Processed 4469208: Folder created with .mp3 and .txt file.
# Processed 4469291: Folder created with .mp3 and .txt file.
# Processed 4469528: Folder created with .mp3 and .txt file.
# Processed 4469590: Folder created with .mp3 and .txt file.
# Processed 4469669: Folder created with .mp3 and .txt file.
# Processed 4469836: Folder created with .mp3 and .txt file.
# Processed 4470010: Folder created with .mp3 and .txt file.
# Processed 4470253: Folder created with .mp3 and .txt file.
# Processed 4470290: Folder created with .mp3 and .txt file.
# Processed 4470570: Folder created with .mp3 and .txt file.
# Processed 4470595: Folder created with .mp3 and .txt file.
# Processed 4470663: Folder created with .mp3 and .txt file.
# Processed 4470684: Folder created with .mp3 and .txt file.
# Processed 4471586: Folder created with .mp3 and .txt file.
# Processed 4471606: Folder created with .mp3 and .txt file.
# Processed 4471809: Folder created with .mp3 and .txt file.
# Processed 4471961: Folder created with .mp3 and .txt file.
# Processed 4472403: Folder created with .mp3 and .txt file.
# Processed 4472895: Folder created with .mp3 and .txt file.
# Processed 4473238: Folder created with .mp3 and .txt file.
# Processed 4473837: Folder created with .mp3 and .txt file.
# Processed 4474229: Folder created with .mp3 and .txt file.
# Processed 4474327: Folder created with .mp3 and .txt file.
# Processed 4474506: Folder created with .mp3 and .txt file.
# Processed 4474955: Folder created with .mp3 and .txt file.
# Processed 4475486: Folder created with .mp3 and .txt file.
# Processed 4475604: Folder created with .mp3 and .txt file.
# Processed 4479524: Folder created with .mp3 and .txt file.
# Processed 4479741: Folder created with .mp3 and .txt file.
# Processed 4479944: Folder created with .mp3 and .txt file.
# Processed 4480850: Folder created with .mp3 and .txt file.
# Processed 4481221: Folder created with .mp3 and .txt file.
# Processed 4481552: Folder created with .mp3 and .txt file.
# Processed 4481601: Folder created with .mp3 and .txt file.
# Processed 4481766: Folder created with .mp3 and .txt file.
# Processed 4481904: Folder created with .mp3 and .txt file.
# Processed 4481952: Folder created with .mp3 and .txt file.
# Processed 4481967: Folder created with .mp3 and .txt file.
# Processed 4482110: Folder created with .mp3 and .txt file.
# Processed 4482249: Folder created with .mp3 and .txt file.
# Processed 4482264: Folder created with .mp3 and .txt file.
# Processed 4482311: Folder created with .mp3 and .txt file.
# Processed 4482383: Folder created with .mp3 and .txt file.
# Processed 4482569: Folder created with .mp3 and .txt file.
# Processed 4482609: Folder created with .mp3 and .txt file.
# Processed 4482613: Folder created with .mp3 and .txt file.
# Processed 4482641: Folder created with .mp3 and .txt file.
# Processed 4482682: Folder created with .mp3 and .txt file.
# Processed 4482968: Folder created with .mp3 and .txt file.
# Processed 4482976: Folder created with .mp3 and .txt file.
# Processed 4482983: Folder created with .mp3 and .txt file.
# Processed 4483046: Folder created with .mp3 and .txt file.
# Processed 4483296: Folder created with .mp3 and .txt file.
# Processed 4483297: Folder created with .mp3 and .txt file.
# Processed 4483320: Folder created with .mp3 and .txt file.
# Processed 4483338: Folder created with .mp3 and .txt file.
# Processed 4483506: Folder created with .mp3 and .txt file.
# Processed 4483589: Folder created with .mp3 and .txt file.
# Processed 4483623: Folder created with .mp3 and .txt file.
# Processed 4483633: Folder created with .mp3 and .txt file.
# Processed 4483668: Folder created with .mp3 and .txt file.
# Processed 4483670: Folder created with .mp3 and .txt file.
# Processed 4483678: Folder created with .mp3 and .txt file.
# Processed 4483680: Folder created with .mp3 and .txt file.
# Processed 4483733: Folder created with .mp3 and .txt file.
# Processed 4483857: Folder created with .mp3 and .txt file.
# Processed 4483912: Folder created with .mp3 and .txt file.
# Processed 4483937: Folder created with .mp3 and .txt file.
# Processed 4484088: Folder created with .mp3 and .txt file.
# Processed 4484146: Folder created with .mp3 and .txt file.
# Processed 4484563: Folder created with .mp3 and .txt file.
# Processed 4484942: Folder created with .mp3 and .txt file.
# Processed 4485192: Folder created with .mp3 and .txt file.
# Processed 4485206: Folder created with .mp3 and .txt file.
# Processed 4485244: Folder created with .mp3 and .txt file.
# Processed MP3-A: Folder created with .mp3 and .txt file.
# Processed MTN-Ghana-2021-Third-Quarter-Results-Call: Folder created with .mp3 and .txt file.
# Processed mtngh_fy18_call_audio_04032019: Folder created with .mp3 and .txt file.
